# %% [markdown]
# # TLB-8800 discovery
#
# Run this notebook from the **Laser** folder (`hardware/Laser`).
#
# - `discovery.py` + `supported_models.json` — find lasers on COM ports
# - `newfocus/TLB8800.py` — connect and control the laser

# %%
import sys
from pathlib import Path

root = Path.cwd()
if str(root) not in sys.path:
    sys.path.insert(0, str(root))

from discovery import LaserDiscovery, list_usb_ports
from newfocus import program_data_lab_root

discovery = LaserDiscovery()
print("Config:", discovery.config_path)
print("Supported:", [m.model for m in discovery.supported_models])
print("Log root:", program_data_lab_root())
print("USB COM ports:", list_usb_ports())
lasers = discovery.discover()
lasers
# Out:
# Config: C:\Users\ModeLabQBI\LAB\hardware\Laser\supported_models.json
# Supported: ['TLB-8800']
# Log root: C:\ProgramData\LAB
# USB COM ports: ['COM4', 'COM5', 'COM3']
# {'COM3': 'New Focus;TLM8700;TLB-8800-0056;2.6.0;2122'}

# %%
from newfocus import TLB8800

port, laser_id = next(iter(lasers.items()))
print("Port:", port)
print("ID:", laser_id)

laser = TLB8800.connect(port)
print("Log file:", laser.log_path)

specs = laser.specs
print("Current control:", specs.current_control)
print("Wavelength range:", specs.wavelength_min, "-", specs.wavelength_max, "nm")
print("Scan speed range:", specs.scan_speed_min, "-", specs.scan_speed_max)
print("Power setpoint:", specs.power)
print("Current:", specs.current, "mA (max", specs.current_max, ")")
print('Trigger Polarity', )
laser
# Out:
# Port: COM3
# ID: New Focus;TLM8700;TLB-8800-0056;2.6.0;2122
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# Cell In[4], line 7
#       3 port, laser_id = next(iter(lasers.items()))
#       4 print("Port:", port)
#       5 print("ID:", laser_id)
#       6
# ----> 7 laser = TLB8800.connect(port)
#       8 print("Log file:", laser.log_path)
#       9
#      10 specs = laser.specs
#
# File c:\Users\ModeLabQBI\LAB\hardware\Laser\newfocus\TLB8800.py:85, in TLB8800.connect(cls, port, baudrate, timeout, enable_log, refresh_specs)
#      74 @classmethod
#      75 def connect(
#      76     cls,
#    (...)     82     refresh_specs: bool = True,
#      83 ) -> "TLB8800":
#      84     """Open serial port; optional session log under ProgramData."""
# ---> 85     transport = SerialTransport(port, baudrate=baudrate, timeout=timeout)
#      86     session_log: Optional[LaserSessionLogger] = None
#      88     if enable_log:
#
# File c:\Users\ModeLabQBI\LAB\hardware\Laser\newfocus\tlb8800_utilities\protocol.py:32, in SerialTransport.__init__(self, port, baudrate, timeout, write_timeout)
#      23 def __init__(
#      24     self,
#      25     port: str,
#    (...)     29     write_timeout: float = DEFAULT_TIMEOUT,
#      30 ) -> None:
#      31     self.port = port
# ---> 32     self._serial = serial.Serial(
#      33         port=port,
#      34         baudrate=baudrate,
#      35         bytesize=serial.EIGHTBITS,
#      36         parity=serial.PARITY_NONE,
#      37         stopbits=serial.STOPBITS_ONE,
#      38         timeout=timeout,
#      39         write_timeout=write_timeout,
#      40     )
#
# File c:\Users\ModeLabQBI\anaconda3\envs\lasers_env\Lib\site-packages\serial\serialwin32.py:33, in Serial.__init__(self, *args, **kwargs)
#      31 self._overlapped_read = None
#      32 self._overlapped_write = None
# ---> 33 super(Serial, self).__init__(*args, **kwargs)
#
# File c:\Users\ModeLabQBI\anaconda3\envs\lasers_env\Lib\site-packages\serial\serialutil.py:244, in SerialBase.__init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     241     raise ValueError('unexpected keyword arguments: {!r}'.format(kwargs))
#     243 if port is not None:
# --> 244     self.open()
#
# File c:\Users\ModeLabQBI\anaconda3\envs\lasers_env\Lib\site-packages\serial\serialwin32.py:64, in Serial.open(self)
#      62 if self._port_handle == win32.INVALID_HANDLE_VALUE:
#      63     self._port_handle = None    # 'cause __del__ is called anyway
# ---> 64     raise SerialException("could not open port {!r}: {!r}".format(self.portstr, ctypes.WinError()))
#      66 try:
#      67     self._overlapped_read = win32.OVERLAPPED()
#
# SerialException: could not open port 'COM3': PermissionError(13, 'Access is denied.', None, 5)

# %%
laser.read.trigger_polarity()
# Out:
# <TriggerPolarity.ACTIVE_HIGH: 1>

# %%
laser.read.trigger_polarity()
# Out:
# <TriggerPolarity.ACTIVE_HIGH: 1>

# %%
from newfocus import TriggerPolarity

# %%
TriggerPolarity.ACTIVE_LOW
# Out:
# <TriggerPolarity.ACTIVE_LOW: 0>

# %%
from newfocus import TriggerPolarity
laser.set.trigger_polarity(TriggerPolarity.ACTIVE_LOW)
# Out:
# CommandResult(command='trpol 0', response='*', ok=True, message='Command accepted.', error_codes=(), error_messages=())

# %%
laser.read.trigger_polarity()
# Out:
# <TriggerPolarity.ACTIVE_LOW: 0>

# %%
print("OPC:", laser.read.operation_complete())
print("Interlock:", laser.read.interlock_state())
print("Laser out:", laser.read.laser_output())
# Out:
# OPC: 1
# Interlock: 0
# Laser out: True

# %%
print(laser.ON())
print("Laser out:", laser.read.laser_output())
# Out:
# OK ('*'): Command accepted.
# Laser out: True

# %%
laser.set.start_scan()
# Out:
# CommandResult(command='scan', response='*', ok=True, message='Command accepted.', error_codes=(), error_messages=())

# %%
laser.read.scan_cycles_count()
# Out:
# 0

# %%
laser.read.scan_cycles()
# Out:
# 4

# %%
laser.read.current()
# Out:
# 99.1

# %%
laser.read.current_max()
# Out:
# 120.0

# %%
laser.read.scan_mode()
# Out:
# <ScanMode.UNI_FORWARD: 2>

# %%
laser.set.tuning_domain(0)
# Out:
# CommandResult(command='unit 0', response='*', ok=True, message='Command accepted.', error_codes=(), error_messages=())

# %%
laser.read.wavelength_max()
# Out:
# 852.0

# %%
laser.read.wavelength_min()
# Out:
# 835.0

# %%
laser.set.tune(842)
# Out:
# CommandResult(command='wave 842', response='*', ok=True, message='Command accepted.', error_codes=(), error_messages=())

# %%
print(laser.OFF())
#laser.close()
# Out:
# OK ('*'): Command accepted.

# %%
laser.close()
